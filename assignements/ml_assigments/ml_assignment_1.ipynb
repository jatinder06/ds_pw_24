# %% [markdown]
# # ML Assignment-1

# %% [markdown]
# 1. Define Artificial Intelligence (AI).

# %% [markdown]
# Explain the differences between Artificial Intelligence (AI), Machine Learning (ML), Deep Learning (DL), and Data Science (DS)
# How does AI differ from traditional software development
# Provide examples of AI, ML, DL, and DS applications
# Discuss the importance of AI, ML, DL, and DS in today's world
# What is Supervised Learning
# Provide examples of Supervised Learning algorithms
# Explain the process of Supervised Learning
# What are the characteristics of Unsupervised Learning
# Give examples of Unsupervised Learning algorithms
# Describe Semi-Supervised Learning and its significance
# Explain Reinforcement Learning and its applications
# How does Reinforcement Learning differ from Supervised and Unsupervised Learning
# What is the purpose of the Train-Test-Validation split in machine learning
# Explain the significance of the training set
# How do you determine the size of the training, testing, and validation sets
# What are the consequences of improper Train-Test-Validation splits
# Discuss the trade-offs in selecting appropriate split ratios
#  Define model performance in machine learning
#  How do you measure the performance of a machine learning model
#  What is overfitting and why is it problematic
#  Provide techniques to address overfitting
#  Explain underfitting and its implications
#  How can you prevent underfitting in machine learning models
#  Discuss the balance between bias and variance in model performance
#  What are the common techniques to handle missing data
#  Explain the implications of ignoring missing data
#  Discuss the pros and cons of imputation methods.

# %% [markdown]
#  How does missing data affect model performance?
#  Define imbalanced data in the context of machine learning?
#  Discuss the challenges posed by imbalanced data?
#  What techniques can be used to address imbalanced data?
#  Explain the process of up-sampling and down-sampling?
#  When would you use up-sampling versus down-sampling?
#  What is SMOTE and how does it work?
#  Explain the role of SMOTE in handling imbalanced data?
#  Discuss the advantages and limitations of SMOTE?
# Provide examples of scenarios where SMOTE is beneficial?
#  Define data interpolation and its purpose?
#  What are the common methods of data interpolation?
#  Discuss the implications of using data interpolation in machine learning?
#  What are outliers in a dataset?
#  Explain the impact of outliers on machine learning models?
#  Discuss techniques for identifying outliers?
#  How can outliers be handled in a dataset?
#  Compare and contrast Filter, Wrapper, and Embedded methods for feature selection?
#  Provide examples of algorithms associated with each method?
#  Discuss the advantages and disadvantages of each feature selection method?
#  Explain the concept of feature scaling?
#  Describe the process of standardization?
#  How does mean normalization differ from standardization?
#  Discuss the advantages and disadvantages of Min-Max scaling?
#  What is the purpose of unit vector scaling?
#  Define Principle Component Analysis (PCA)?
#  Explain the steps involved in PCA?
#  Discuss the significance of eigenvalues and eigenvectors in PCA?
#  How does PCA help in dimensionality reduction?
#  Define data encoding and its importance in machine learning?
#  Explain Nominal Encoding and provide an example?

# %%
Discuss the process of One Hot EncodingA
How do you handle multiple categories in One Hot Encoding!
Explain Mean Encoding and its advantagesA
Provide examples of Ordinal Encoding and Label EncodingA
What is Target Guided Ordinal Encoding and how is it used!
Define covariance and its significance in statisticsA
Explain the process of correlation checkA
What is the Pearson Correlation Coefficient!
How does Spearman's Rank Correlation differ from Pearson's Correlation!
Discuss the importance of Variance Inflation Factor (VIF) in feature selectionA
Define feature selection and its purposeA
Explain the process of Recursive Feature EliminationA
How does Backward Elimination work!
Discuss the advantages and limitations of Forward EliminationA
What is feature engineering and why is it important!
Discuss the steps involved in feature engineeringA
Provide examples of feature engineering techniquesA
How does feature selection differ from feature engineering!
Explain the importance of feature selection in machine learning pipelinesA
Discuss the impact of feature selection on model performanceA
How do you determine which features to include in a machine-learning model?
